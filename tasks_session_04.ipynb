# %% [markdown]
# <a href="https://colab.research.google.com/github/ayeshashoaib-3000/-student-performance-analysis/blob/main/tasks_session_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SESSION 4 — COMPLETE PRACTICAL CODE

# %% [markdown]
# # TASK 1
# |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


numeric_columns = df.select_dtypes(
    include=["int64", "float64"]
).columns


for column in numeric_columns:

    plt.figure(figsize=(7, 4))

    sns.histplot(
        df[column],
        kde=True
    )

    plt.title(
        "Distribution of " + column
    )

# %%
    plt.xlabel(column)

    plt.ylabel("Frequency")

    plt.show()

# %% [markdown]
# # TASK 2

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['Student_ID', 'Name', 'Age', 'Gender', 'Study_Hours', 'Attendance', 'Assignments', 'Previous_Score', 'Final_Score']
#    Student_ID    Name  Age Gender  Study_Hours  Attendance  Assignments  \
# 0         101     Ali   19      M          3.5          82            7
# 1         102    Sara   20      F          5.0          91            9
# 2         103   Ahmed   19      M          2.0          70            6
# 3         104  Ayesha   20      F          4.5          88            8
# 4         105   Bilal   21      M          1.5          65            5
#
#    Previous_Score  Final_Score
# 0              68           72
# 1              78           85
# 2              55           60
# 3              74           81
# 4              48           52

# %% [markdown]
# # TASK 3 — Correlation Heatmap

# %%
correlation = df.corr(
    numeric_only=True
)


plt.figure(
    figsize=(10, 7)
)


sns.heatmap(
    correlation,
    annot=True,
    cmap="Blues"
)


plt.title(
    "Correlation Heatmap"
)


plt.show()

# %% [markdown]
# # TASK 4 — Detect Outliers Using IQR

# %%
for column in numeric_columns:

    if column == "target":
        continue


    Q1 = df[column].quantile(0.25)

    Q3 = df[column].quantile(0.75)

    IQR = Q3 - Q1


    lower_limit = Q1 - 1.5 * IQR

    upper_limit = Q3 + 1.5 * IQR

    outliers = df[
        (df[column] < lower_limit)
        |
        (df[column] > upper_limit)
    ]


    print("\nColumn:", column)

    print(
        "Number of Outliers:",
        len(outliers)
    )
# Out:
# Column: Age
# Number of Outliers: 0
#
# Column: Study_Hours
# Number of Outliers: 0
#
# Column: Attendance
# Number of Outliers: 0
#
# Column: Assignments
# Number of Outliers: 0
#
# Column: Previous_Score
# Number of Outliers: 0
#
# Column: Final_Score
# Number of Outliers: 0

# %%
#### ### Outlier Treatment

#I used the IQR method to detect possible outliers.

#I would not remove every outlier automatically because an unusual value
#can still be a valid observation.

#First, I would check whether the value is caused by a data-entry error.

#If it is an incorrect value, it may be corrected or removed.

#If the value is genuine, I may keep it.

#For highly skewed numerical features, capping or a log transformation
#can also be considered.

# %% [markdown]
# # TASK 5 — Five Written Insights

# %% [markdown]
# ### Five EDA Insights
#
# 1. The target classes are not completely balanced. The Session 3 example
#    shows an approximate 64% to 36% distribution.
#
# 2. The example age distribution is right-skewed, so median can be a
#    better choice than mean when filling missing values.
#
# 3. The 26–35 age group is the largest group in the distribution shown
#    in the PDF.
#
# 4. Tenure shows the strongest positive relationship with the target in
#    the correlation example.
#
# 5. Support calls show an opposite relationship with the target, while
#    age has relatively little correlation with the target by itself.
